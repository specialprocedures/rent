# %%
import pandas as pd

# Read in data, skipping description rows
rent = pd.read_excel("price_index_private_rent.xlsx", skiprows=7)

# Give the columns names that easier to work with
rent.columns = ["date", "la_code", "la", "region", "annual_change", "rent"]

# Set the date column as date time
rent["date"] = pd.to_datetime(rent["date"])

# Get the year
rent["year"] = rent["date"].dt.year

# Drop Wales, Scotland, Northern Ireland and United Kingdom
rent = rent[
    (~rent["region"].isin(["Wales", "Scotland", "Northern Ireland", "United Kingdom"]))
    & (rent["year"] >= 2020)
]

rent["rent"] = rent["rent"].astype(float)

# %%
deprivation = pd.read_excel("2025_deprivation_scores.xlsx", sheet_name="IoD2025 Scores")
deprivation.columns = [
    "lsoa_code",
    "lsoa_name",
    "la_code",
    "la_name",
    "imd",
    "income",
    "employment",
    "education",
    "health",
    "crime",
    "housing",
    "living_environment",
    "housing",
    "child",
    "older",
    "adult_skills",
    "geo_barriers",
    "wider",
    "indoors",
    "outdoors",
]
deprivation
# Out:
#        lsoa_code                  lsoa_name    la_code               la_name  \
# 0      E01000001        City of London 001A  E09000001        City of London
# 1      E01000002        City of London 001B  E09000001        City of London
# 2      E01000003        City of London 001C  E09000001        City of London
# 3      E01000005        City of London 001E  E09000001        City of London
# 4      E01000006  Barking and Dagenham 016A  E09000002  Barking and Dagenham
# ...          ...                        ...        ...                   ...
# 33750  E01035758   Vale of White Horse 014H  E07000180   Vale of White Horse
# 33751  E01035759   Vale of White Horse 015G  E07000180   Vale of White Horse
# 33752  E01035760   Vale of White Horse 015H  E07000180   Vale of White Horse
# 33753  E01035761   Vale of White Horse 015I  E07000180   Vale of White Horse
# 33754  E01035762      West Oxfordshire 004H  E07000181      West Oxfordshire
#
#           imd  income  employment  education  health  crime  housing  \
# 0       8.742   0.013       0.014      0.004  -1.771 -2.220   10.950
# 1       4.722   0.018       0.010      0.169  -1.549 -2.277    6.703
# 2       9.250   0.107       0.064      3.269  -0.292 -0.765    9.735
# 3      19.884   0.211       0.104     17.852   0.436 -0.626   24.623
# 4      25.307   0.343       0.120     25.442  -0.372 -0.072   38.025
# ...       ...     ...         ...        ...     ...    ...      ...
# 33750   7.945   0.101       0.074     10.893  -1.004  0.215   15.321
# 33751   7.622   0.097       0.081      7.528  -0.645 -1.047   23.669
# 33752   7.946   0.170       0.067     10.064  -0.743 -0.157   10.074
# 33753   6.682   0.136       0.054      8.482  -0.938 -0.566   19.265
# 33754  10.819   0.106       0.061      5.535  -0.570 -0.999   35.128
#
#        living_environment  housing  child  older  adult_skills  geo_barriers  \
# 0                  69.345    0.039  0.012 -2.902         0.030         4.437
# 1                  43.890    0.076  0.026 -1.830         0.032         3.589
# 2                  41.163    0.250  0.153 -0.756         0.113         2.509
# 3                  38.695    0.459  0.625 -0.814         0.305         2.914
# 4                  29.616    0.640  0.156 -0.199         0.336        13.049
# ...                   ...      ...    ...    ...           ...           ...
# 33750               8.503    0.192  0.069  0.079         0.143        31.877
# 33751               5.731    0.162  0.091 -0.245         0.137        49.863
# 33752               3.450    0.206  0.316  0.084         0.122        31.757
# 33753               4.985    0.212  0.070 -0.054         0.116        44.211
# 33754              24.198    0.225  0.050 -0.402         0.119        69.021
#
#        wider  indoors  outdoors
# 0      0.688    1.207     1.414
# 1     -0.628    0.355     1.839
# 2      0.358    0.318     1.679
# 3      4.091    0.012     2.065
# 4      6.204    0.399     0.400
# ...      ...      ...       ...
# 33750 -0.124   -0.386    -0.309
# 33751 -1.960   -0.628    -0.313
# 33752 -2.305   -1.794    -0.250
# 33753 -2.328   -1.459    -0.044
# 33754 -1.649    0.435    -0.421
#
# [33755 rows x 20 columns]

# %%
mismatches = [
    i for i in deprivation["la_code"].unique() if i not in rent["la_code"].unique()
]
print(mismatches)
# Out:
# ['E09000001', 'E08000016', 'E08000019', 'E06000053']

# %%
remap = {
    "E08000016": "E08000038",  # Barnsley
    "E08000019": "E08000039",  # Sheffield
}
deprivation["la_code"] = deprivation["la_code"].replace(remap)

# Isles of Scilly and City of London
drop = ["E06000053", "E09000001"]
deprivation = deprivation[~deprivation["la_code"].isin(drop)]

# %%
df = rent.merge(
    deprivation.groupby(["la_code", "la_name"])[["imd", "income"]].mean().reset_index(),
    on="la_code",
    how="left",
)

inverse_map = {v: k for k, v in remap.items()}
df["la_code"] = df["la_code"].replace(inverse_map)

# %%
import plotly.express as px


def calculate_cumulative_pct_change(group):
    baseline = group.iloc[0]
    return ((group - baseline) / baseline) * 100


grouped_rent = df.groupby("la_code")["rent"]
df["cum_pct"] = grouped_rent.transform(calculate_cumulative_pct_change)

to_plot = df[["date", "la_name", "region", "cum_pct"]].copy()

regional_averages = to_plot.groupby(["region", "date"])["cum_pct"].mean().reset_index()
regional_averages["la_name"] = "Regional Average"

# Calculate national average
national_average = to_plot.groupby("date")["cum_pct"].mean().reset_index()
national_average["la_name"] = "National Average"

# Define region order
region_order = [
    "North West",
    "Yorkshire and The Humber",
    "North East",
    "West Midlands",
    "East Midlands",
    "East of England",
    "South West",
    "London",
    "South East",
]

# Set region as categorical with specified order
to_plot["region"] = pd.Categorical(
    to_plot["region"], categories=region_order, ordered=True
)
to_plot = to_plot.sort_values(["region", "date"])

to_plot = pd.concat([to_plot, regional_averages], ignore_index=True)

# Calculate endline percent change for each region and national average
endline_changes = (
    regional_averages.sort_values("date").groupby("region")["cum_pct"].last()
)
national_endline = national_average["cum_pct"].iloc[-1]

fig = px.line(
    to_plot,
    x="date",
    y="cum_pct",
    color="la_name",
    facet_col="region",
    facet_col_wrap=3,
    category_orders={"region": region_order},
    title="Private Rent Change Over Time by Local Authority",
    labels={"cum_pct": "", "date": "Date"},
    # width=1080,
    # height=768,
    # responsive=True,
)

# Set transparency for all lines but regional averages
# Corporate colors: rgb(10, 255, 206), rgb(244, 240, 231), rgb(21, 38, 58)
for trace in fig.data:
    if trace.name != "Regional Average":
        trace.update(
            line=dict(width=1),
            opacity=0.3,
            hovertemplate="<b>%{fullData.name}</b><br>%{y:.1f}%<extra></extra>",
        )
    else:
        trace.update(
            line=dict(color="rgb(21, 38, 58)", width=2),
            hovertemplate="<b>%{fullData.name}</b><br>%{y:.1f}%<extra></extra>",
        )

# Add hover behavior via layout
fig.update_layout(
    showlegend=False,
    hovermode="closest",
    hoverdistance=100,
    plot_bgcolor="rgb(244, 240, 231)",
    paper_bgcolor="rgb(244, 240, 231)",
    title=dict(
        text=f"<b>Cumulative rent change as a proportion of 2020 baseline</b><br>National average: {national_endline:.0f}%",
        y=0.965,
        yanchor="top",
    ),
    margin=dict(t=120),
)

# Lock axes and hide modebar
fig.update_xaxes(fixedrange=True)
fig.update_yaxes(fixedrange=True)

# Remove gridlines and update facet titles
fig.update_xaxes(
    showgrid=False, title_text="", tickfont=dict(size=12), title_standoff=25
)
fig.update_yaxes(
    showgrid=False,
    title_text="",
    range=[-20, 80],
    tickfont=dict(size=12),
    title_standoff=25,
)

# Change "region=X" to "X" in facet titles
fig.for_each_annotation(
    lambda a: a.update(
        text=f"{a.text.split('=')[-1]}<br>{endline_changes.get(a.text.split('=')[-1], 0):.0f}%",
        font=dict(size=14),
    )
)

fig.show()
fig.write_html("private_rent_change_by_la.html", config={"displayModeBar": False})

# %%
# Regional baseline/endline in absolute and relative terms
la_rent = df.groupby(["la_code", "date"])["rent"].mean().reset_index()

# Get baseline and endline for each region
la_baseline = la_rent.sort_values("date").groupby("la_code")["rent"].first()
la_endline = la_rent.sort_values("date").groupby("la_code")["rent"].last()

# Calculate changes
la_stats = pd.DataFrame(
    {
        "baseline": la_baseline,
        "endline": la_endline,
        "absolute": la_endline - la_endline,
        "pct_change": ((la_endline - la_baseline) / la_baseline) * 100,
    }
)

# Merge back to df
la_stats = (
    la_stats.sort_values("pct_change", ascending=False)
    .reset_index()
    .merge(df[["la_code", "la_name", "region", "imd", "income"]], how="left")
    .drop_duplicates()
    .assign(rent_risk_index=lambda x: x["pct_change"] * x["income"])
)

# Normalise index
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 100))
la_stats["rent_risk_index"] = scaler.fit_transform(la_stats[["rent_risk_index"]])

# %%
print(
    la_stats.sort_values("rent_risk_index", ascending=False)[
        ["la_name", "region", "rent_risk_index"]
    ]
    .assign(rent_risk_index=lambda x: x["rent_risk_index"].astype(int))
    .head(10)
    .to_markdown(index=False)
)
# Out:
# | la_name       | region        |   rent_risk_index |
# |:--------------|:--------------|------------------:|
# | Tameside      | North West    |               100 |
# | Rochdale      | North West    |                99 |
# | Oldham        | North West    |                94 |
# | Manchester    | North West    |                93 |
# | Liverpool     | North West    |                88 |
# | Nottingham    | East Midlands |                87 |
# | Birmingham    | West Midlands |                86 |
# | Sandwell      | West Midlands |                86 |
# | Salford       | North West    |                82 |
# | Wolverhampton | West Midlands |                81 |

# %%
# Get regional ranks by deprivation (imd)
la_stats["imd_rank"] = la_stats["imd"].rank(method="first", ascending=False)

print(
    la_stats.sort_values("imd_rank", ascending=True)[
        ["la_name", "region", "imd_rank", "imd"]
    ].to_markdown(index=True)
)
# Out:
# |       | la_name                             | region                   |   imd_rank |      imd |
# |------:|:------------------------------------|:-------------------------|-----------:|---------:|
# | 18630 | Blackpool                           | North West               |          1 | 43.5275  |
# | 11868 | Middlesbrough                       | North East               |          2 | 40.9287  |
# |   759 | Manchester                          | North West               |          3 | 37.9629  |
# | 20286 | Hartlepool                          | North East               |          4 | 37.8621  |
# |  3795 | Birmingham                          | West Midlands            |          5 | 37.4801  |
# | 13593 | Hastings                            | South East               |          6 | 37.4229  |
# | 12213 | Kingston upon Hull, City of         | Yorkshire and The Humber |          7 | 37.0708  |
# |   621 | Liverpool                           | North West               |          8 | 36.963   |
# | 13455 | Burnley                             | North West               |          9 | 36.9357  |
# |  3588 | Knowsley                            | North West               |         10 | 36.8826  |
# |  2208 | Blackburn with Darwen               | North West               |         11 | 36.6829  |
# | 14007 | Bradford                            | Yorkshire and The Humber |         12 | 35.7047  |
# |  1035 | Nottingham                          | East Midlands            |         13 | 35.0477  |
# |   414 | Oldham                              | North West               |         14 | 34.6739  |
# |  8625 | Hyndburn                            | North West               |         15 | 34.58    |
# |  5589 | Pendle                              | North West               |         16 | 33.9763  |
# |  1587 | Leicester                           | East Midlands            |         17 | 33.9324  |
# |  9177 | Great Yarmouth                      | East of England          |         18 | 33.8631  |
# |  1794 | Sandwell                            | West Midlands            |         19 | 33.4322  |
# |   138 | Rochdale                            | North West               |         20 | 33.2408  |
# |  4554 | Stoke-on-Trent                      | West Midlands            |         21 | 33.0125  |
# | 16422 | Sunderland                          | North East               |         22 | 32.7486  |
# | 15249 | Halton                              | North West               |         23 | 32.0667  |
# |  3243 | Tendring                            | East of England          |         24 | 31.907   |
# |  1656 | Wolverhampton                       | West Midlands            |         25 | 31.8575  |
# | 14214 | Hackney                             | London                   |         26 | 31.7713  |
# |   345 | Salford                             | North West               |         27 | 31.452   |
# |  2070 | Thanet                              | South East               |         28 | 31.3792  |
# | 18009 | Newham                              | London                   |         29 | 31.3531  |
# |  8901 | South Tyneside                      | North East               |         30 | 31.2958  |
# | 13524 | Redcar and Cleveland                | North East               |         31 | 30.7034  |
# |  3381 | Walsall                             | West Midlands            |         32 | 30.6725  |
# | 19734 | North East Lincolnshire             | Yorkshire and The Humber |         33 | 30.6225  |
# | 16905 | Doncaster                           | Yorkshire and The Humber |         34 | 30.4667  |
# | 19182 | Tower Hamlets                       | London                   |         35 | 30.4354  |
# | 17595 | East Lindsey                        | East Midlands            |         36 | 30.2762  |
# |  6141 | Barking and Dagenham                | London                   |         37 | 30.2743  |
# |  1311 | Bolton                              | North West               |         38 | 30.2626  |
# |  6555 | Barnsley                            | Yorkshire and The Humber |         39 | 30.2451  |
# | 10488 | Haringey                            | London                   |         40 | 30.0443  |
# |  9660 | Brent                               | London                   |         41 | 29.9831  |
# | 15801 | County Durham                       | North East               |         42 | 29.8496  |
# | 13938 | Rotherham                           | Yorkshire and The Humber |         43 | 29.4606  |
# |  7797 | Enfield                             | London                   |         44 | 29.2113  |
# |     0 | Tameside                            | North West               |         45 | 29.1994  |
# |  4416 | Lincoln                             | East Midlands            |         46 | 28.9972  |
# |  1173 | St. Helens                          | North West               |         47 | 28.8288  |
# | 16491 | Boston                              | East Midlands            |         48 | 28.758   |
# |  1449 | Newcastle upon Tyne                 | North East               |         49 | 28.6725  |
# |  6900 | Luton                               | East of England          |         50 | 28.6507  |
# | 12696 | Preston                             | North West               |         51 | 28.634   |
# |  4899 | Calderdale                          | Yorkshire and The Humber |         52 | 28.0279  |
# |  4140 | Gateshead                           | North East               |         53 | 27.9981  |
# | 10005 | Wakefield                           | Yorkshire and The Humber |         54 | 27.344   |
# |  8211 | Peterborough                        | East of England          |         55 | 27.27    |
# |  6831 | Wirral                              | North West               |         56 | 27.2031  |
# |  7728 | Coventry                            | West Midlands            |         57 | 27.0568  |
# |  7176 | Sheffield                           | Yorkshire and The Humber |         58 | 27.0484  |
# |    69 | Rossendale                          | North West               |         59 | 26.9496  |
# |  1725 | Mansfield                           | East Midlands            |         60 | 26.8701  |
# |  6072 | Swale                               | South East               |         61 | 26.7029  |
# |  5175 | Derby                               | East Midlands            |         62 | 26.6022  |
# |  8970 | Darlington                          | North East               |         63 | 26.5594  |
# | 14835 | Islington                           | London                   |         64 | 26.5352  |
# |  8142 | Norwich                             | East of England          |         65 | 26.4716  |
# |  8349 | Fenland                             | East of England          |         66 | 26.3208  |
# | 18354 | Torbay                              | South West               |         67 | 26.2759  |
# |  9384 | Stockton-on-Tees                    | North East               |         68 | 26.2558  |
# |  3450 | Portsmouth                          | South East               |         69 | 25.8261  |
# |   828 | Ashfield                            | East Midlands            |         70 | 25.8176  |
# |  5796 | Southampton                         | South East               |         71 | 25.6396  |
# |  2346 | Bolsover                            | East Midlands            |         72 | 25.457   |
# |   483 | Folkestone and Hythe                | South East               |         73 | 25.4358  |
# |  3036 | Ealing                              | London                   |         74 | 25.4205  |
# | 12144 | Lewisham                            | London                   |         75 | 25.3957  |
# | 18699 | Kirklees                            | Yorkshire and The Humber |         76 | 25.3427  |
# |  1863 | Sefton                              | North West               |         77 | 25.2757  |
# | 10971 | Chesterfield                        | East Midlands            |         78 | 25.2267  |
# |  6003 | Ipswich                             | East of England          |         79 | 25.0574  |
# |  2967 | Wigan                               | North West               |         80 | 25.0492  |
# |  9936 | Dover                               | South East               |         81 | 24.7971  |
# | 14076 | Telford and Wrekin                  | West Midlands            |         82 | 24.5955  |
# | 12558 | Isle of Wight                       | South East               |         83 | 24.5143  |
# |  2001 | Hounslow                            | London                   |         84 | 24.5119  |
# |  3174 | Medway                              | South East               |         85 | 24.1873  |
# | 11454 | Cumberland                          | North West               |         86 | 24.1003  |
# |  6417 | Plymouth                            | South West               |         87 | 23.9589  |
# |  4485 | King's Lynn and West Norfolk        | East of England          |         88 | 23.8135  |
# | 10281 | Leeds                               | Yorkshire and The Humber |         89 | 23.7258  |
# |   690 | Nuneaton and Bedworth               | West Midlands            |         90 | 23.6716  |
# |  2691 | Gosport                             | South East               |         91 | 23.6608  |
# | 15180 | Eastbourne                          | South East               |         92 | 23.6508  |
# | 17871 | Westminster                         | London                   |         93 | 23.6507  |
# | 10419 | Torridge                            | South West               |         94 | 23.6504  |
# | 20010 | Camden                              | London                   |         95 | 23.3346  |
# | 16836 | Lancaster                           | North West               |         96 | 23.3276  |
# | 16008 | Waltham Forest                      | London                   |         97 | 23.2691  |
# | 17112 | North Lincolnshire                  | Yorkshire and The Humber |         98 | 23.2487  |
# |  9453 | Lambeth                             | London                   |         99 | 23.2043  |
# | 17250 | Southend-on-Sea                     | East of England          |        100 | 23.1361  |
# | 14628 | Greenwich                           | London                   |        101 | 23.1234  |
# |  8487 | Bassetlaw                           | East Midlands            |        102 | 23.0664  |
# | 16974 | Southwark                           | London                   |        103 | 23.0385  |
# |   207 | Bury                                | North West               |        104 | 22.9915  |
# | 10557 | Gravesham                           | South East               |        105 | 22.864   |
# |  2415 | Slough                              | South East               |        106 | 22.7078  |
# | 10764 | Rother                              | South East               |        107 | 22.5798  |
# | 11178 | Cornwall                            | South West               |        108 | 22.4862  |
# |  7935 | North Devon                         | South West               |        109 | 22.4513  |
# | 19320 | Wyre                                | North West               |        110 | 22.4248  |
# |  3105 | Dudley                              | West Midlands            |        111 | 22.2638  |
# |  4209 | Bristol, City of                    | South West               |        112 | 22.2555  |
# | 16629 | Northumberland                      | North East               |        113 | 22.1485  |
# |  9522 | West Lindsey                        | East Midlands            |        114 | 22.1108  |
# | 10695 | Croydon                             | London                   |        115 | 22.1067  |
# | 14559 | Basildon                            | East of England          |        116 | 22.0606  |
# | 13248 | Havant                              | South East               |        117 | 21.9462  |
# |  6348 | Harlow                              | East of England          |        118 | 21.8749  |
# |  3726 | Wyre Forest                         | West Midlands            |        119 | 21.3351  |
# |   966 | Gloucester                          | South West               |        120 | 21.3007  |
# | 16767 | North Norfolk                       | East of England          |        121 | 21.2751  |
# |  6624 | Hammersmith and Fulham              | London                   |        122 | 21.0963  |
# |  9108 | North Tyneside                      | North East               |        123 | 21.0943  |
# | 18423 | South Holland                       | East Midlands            |        124 | 21.0452  |
# |  6210 | East Suffolk                        | East of England          |        125 | 20.7683  |
# |  6279 | Tamworth                            | West Midlands            |        126 | 20.6942  |
# |  2277 | Erewash                             | East Midlands            |        127 | 20.6649  |
# | 18492 | Thurrock                            | East of England          |        128 | 20.6364  |
# | 11316 | Crawley                             | South East               |        129 | 20.5764  |
# | 11799 | Kensington and Chelsea              | London                   |        130 | 20.4558  |
# |  5037 | Cannock Chase                       | West Midlands            |        131 | 20.3792  |
# | 16215 | Brighton and Hove                   | South East               |        132 | 20.3564  |
# |  9729 | Breckland                           | East of England          |        133 | 20.3135  |
# |  2898 | North Warwickshire                  | West Midlands            |        134 | 20.0271  |
# |  5865 | Hillingdon                          | London                   |        135 | 20.0186  |
# |  2760 | Ashford                             | South East               |        136 | 19.8691  |
# | 19665 | Redditch                            | West Midlands            |        137 | 19.8626  |
# | 19803 | Canterbury                          | South East               |        138 | 19.8384  |
# | 16077 | Worcester                           | West Midlands            |        139 | 19.7372  |
# | 15387 | Mid Devon                           | South West               |        140 | 19.4191  |
# |  6693 | Bedford                             | East of England          |        141 | 19.4041  |
# |  5520 | Somerset                            | South West               |        142 | 19.3332  |
# |  5934 | Arun                                | South East               |        143 | 19.329   |
# | 11592 | Redbridge                           | London                   |        144 | 19.283   |
# |  4347 | Forest of Dean                      | South West               |        145 | 19.2023  |
# | 14490 | Barnet                              | London                   |        146 | 19.0994  |
# |  4002 | Stevenage                           | East of England          |        147 | 19.0267  |
# | 16698 | Newcastle-under-Lyme                | West Midlands            |        148 | 18.975   |
# | 18216 | West Devon                          | South West               |        149 | 18.9541  |
# |  5382 | Newark and Sherwood                 | East Midlands            |        150 | 18.8846  |
# |  7245 | North Northamptonshire              | East Midlands            |        151 | 18.8552  |
# | 15732 | Herefordshire, County of            | West Midlands            |        152 | 18.8432  |
# | 12765 | East Staffordshire                  | West Midlands            |        153 | 18.7914  |
# |  4968 | Amber Valley                        | East Midlands            |        154 | 18.7127  |
# | 12903 | West Lancashire                     | North West               |        155 | 18.7018  |
# | 15663 | Westmorland and Furness             | North West               |        156 | 18.6344  |
# | 12420 | Reading                             | South East               |        157 | 18.5528  |
# | 14145 | Milton Keynes                       | South East               |        158 | 18.3982  |
# |  9246 | North East Derbyshire               | East Midlands            |        159 | 18.3768  |
# |  4278 | Maidstone                           | South East               |        160 | 18.3396  |
# | 10143 | High Peak                           | East Midlands            |        161 | 18.2152  |
# |  1518 | Cheshire West and Chester           | North West               |        162 | 18.0409  |
# | 12489 | Shropshire                          | West Midlands            |        163 | 17.9301  |
# |   552 | Stockport                           | North West               |        164 | 17.8513  |
# |  2484 | Colchester                          | East of England          |        165 | 17.8036  |
# | 18561 | Castle Point                        | East of England          |        166 | 17.7967  |
# |  2553 | Dartford                            | South East               |        167 | 17.5419  |
# |  5727 | Broxbourne                          | East of England          |        168 | 17.487   |
# |  3312 | Bournemouth, Christchurch and Poole | South West               |        169 | 17.4829  |
# |  7659 | Swindon                             | South West               |        170 | 17.3795  |
# |  5313 | Solihull                            | West Midlands            |        171 | 17.3717  |
# | 15870 | Teignbridge                         | South West               |        172 | 17.1747  |
# | 15939 | Harrow                              | London                   |        173 | 17.0321  |
# |  2622 | Braintree                           | East of England          |        174 | 16.8807  |
# |  7521 | Chorley                             | North West               |        175 | 16.7696  |
# | 18837 | Lewes                               | South East               |        176 | 16.7165  |
# |  7590 | Warrington                          | North West               |        177 | 16.7134  |
# | 13317 | West Northamptonshire               | East Midlands            |        178 | 16.5223  |
# |  4071 | Watford                             | East of England          |        179 | 16.4143  |
# | 12834 | Malvern Hills                       | West Midlands            |        180 | 16.2397  |
# | 18768 | Dorset                              | South West               |        181 | 16.1811  |
# | 17457 | East Riding of Yorkshire            | Yorkshire and The Humber |        182 | 16.1244  |
# | 15525 | West Suffolk                        | East of England          |        183 | 16.1098  |
# |  6762 | Exeter                              | South West               |        184 | 16.0574  |
# | 18078 | North Yorkshire                     | Yorkshire and The Humber |        185 | 15.9366  |
# |  4761 | Havering                            | London                   |        186 | 15.9282  |
# | 18975 | Wychavon                            | West Midlands            |        187 | 15.9071  |
# |  8694 | Fylde                               | North West               |        188 | 15.8485  |
# | 17664 | Maldon                              | East of England          |        189 | 15.7353  |
# | 12282 | North West Leicestershire           | East Midlands            |        190 | 15.6912  |
# | 12627 | Chichester                          | South East               |        191 | 15.6833  |
# |  6969 | Worthing                            | South East               |        192 | 15.6616  |
# | 15042 | Babergh                             | East of England          |        193 | 15.5002  |
# |  1242 | North Somerset                      | South West               |        194 | 15.336   |
# | 13800 | Melton                              | East Midlands            |        195 | 15.1831  |
# |  9867 | South Hams                          | South West               |        196 | 15.1532  |
# | 13041 | Rushmoor                            | South East               |        197 | 15.1268  |
# | 17388 | South Kesteven                      | East Midlands            |        198 | 15.0001  |
# |  4692 | Adur                                | South East               |        199 | 14.962   |
# |  9039 | Staffordshire Moorlands             | West Midlands            |        200 | 14.9493  |
# |   276 | Trafford                            | North West               |        201 | 14.874   |
# | 14352 | Wandsworth                          | London                   |        202 | 14.8728  |
# |  1380 | Bexley                              | London                   |        203 | 14.8504  |
# | 11455 | West Northamptonshire               | North West               |        204 | 14.839   |
# | 11109 | Oxford                              | South East               |        205 | 14.7627  |
# | 17319 | Spelthorne                          | South East               |        206 | 14.7538  |
# | 10626 | Mid Suffolk                         | East of England          |        207 | 14.7456  |
# |  3657 | Gedling                             | East Midlands            |        208 | 14.7315  |
# |  9315 | South Derbyshire                    | East Midlands            |        209 | 14.645   |
# | 13110 | South Ribble                        | North West               |        210 | 14.6219  |
# | 13179 | Sevenoaks                           | South East               |        211 | 14.5176  |
# | 18906 | East Devon                          | South West               |        212 | 14.5153  |
# |  8418 | Stafford                            | West Midlands            |        213 | 14.2716  |
# | 16560 | Hertsmere                           | East of England          |        214 | 14.2318  |
# | 15111 | Cheshire East                       | North West               |        215 | 14.1484  |
# |  7452 | Tunbridge Wells                     | South East               |        216 | 14.0428  |
# |  1104 | Broxtowe                            | East Midlands            |        217 | 14.0325  |
# | 12075 | Merton                              | London                   |        218 | 14.0174  |
# | 14973 | Welwyn Hatfield                     | East of England          |        219 | 13.9853  |
# | 13662 | Rugby                               | West Midlands            |        220 | 13.9602  |
# | 20148 | Derbyshire Dales                    | East Midlands            |        221 | 13.8962  |
# | 14283 | Dacorum                             | East of England          |        222 | 13.8392  |
# |  2139 | Hinckley and Bosworth               | East Midlands            |        223 | 13.8166  |
# | 14421 | Wiltshire                           | South West               |        224 | 13.7333  |
# | 11247 | South Staffordshire                 | West Midlands            |        225 | 13.6475  |
# | 19044 | Epping Forest                       | East of England          |        226 | 13.6238  |
# |  5244 | Sutton                              | London                   |        227 | 13.5524  |
# |  1932 | Oadby and Wigston                   | East Midlands            |        228 | 13.3978  |
# |  2829 | Charnwood                           | East Midlands            |        229 | 13.335   |
# |  8073 | South Norfolk                       | East of England          |        230 | 13.2051  |
# |  9798 | North Kesteven                      | East Midlands            |        231 | 13.0691  |
# | 11730 | New Forest                          | South East               |        232 | 13.0003  |
# |  3519 | Chelmsford                          | East of England          |        233 | 12.979   |
# |  7038 | Cheltenham                          | South West               |        234 | 12.9384  |
# | 12006 | Tonbridge and Malling               | South East               |        235 | 12.8902  |
# |  5658 | Lichfield                           | West Midlands            |        236 | 12.876   |
# | 13869 | Wealden                             | South East               |        237 | 12.8507  |
# | 12351 | Central Bedfordshire                | East of England          |        238 | 12.8418  |
# | 18285 | Tandridge                           | South East               |        239 | 12.7362  |
# |  9591 | Stroud                              | South West               |        240 | 12.721   |
# |  7314 | Basingstoke and Deane               | South East               |        241 | 12.7203  |
# |  4830 | Bath and North East Somerset        | South West               |        242 | 12.6689  |
# |  4623 | Cherwell                            | South East               |        243 | 12.5931  |
# | 19872 | Runnymede                           | South East               |        244 | 12.5526  |
# | 11661 | Bromley                             | London                   |        245 | 12.5426  |
# | 17043 | East Cambridgeshire                 | East of England          |        246 | 12.3708  |
# | 16146 | Test Valley                         | South East               |        247 | 12.2237  |
# | 14697 | Cambridge                           | East of England          |        248 | 12.155   |
# | 10833 | Broadland                           | East of England          |        249 | 12.1314  |
# | 16353 | York                                | Yorkshire and The Humber |        250 | 12.0615  |
# | 15594 | Cotswold                            | South West               |        251 | 12.0427  |
# | 19458 | Stratford-on-Avon                   | West Midlands            |        252 | 11.8793  |
# | 19251 | Buckinghamshire                     | South East               |        253 | 11.7429  |
# | 16284 | Huntingdonshire                     | East of England          |        254 | 11.7181  |
# | 13731 | Tewkesbury                          | South West               |        255 | 11.5915  |
# |  3864 | North Hertfordshire                 | East of England          |        256 | 11.5581  |
# | 19596 | Rochford                            | East of England          |        257 | 11.5152  |
# |   897 | South Gloucestershire               | South West               |        258 | 11.3848  |
# |  8004 | Bromsgrove                          | West Midlands            |        259 | 11.2137  |
# | 19389 | West Berkshire                      | South East               |        260 | 11.0817  |
# | 17940 | Woking                              | South East               |        261 | 11.0308  |
# | 17526 | Brentwood                           | East of England          |        262 | 11.024   |
# | 17733 | Warwick                             | West Midlands            |        263 | 10.9912  |
# | 12972 | Eastleigh                           | South East               |        264 | 10.8951  |
# |  3933 | Blaby                               | East Midlands            |        265 | 10.761   |
# | 10902 | Kingston upon Thames                | London                   |        266 | 10.7413  |
# | 14766 | Winchester                          | South East               |        267 | 10.5798  |
# | 17802 | Ribble Valley                       | North West               |        268 | 10.355   |
# | 18147 | West Oxfordshire                    | South East               |        269 | 10.1999  |
# | 11937 | Uttlesford                          | East of England          |        270 | 10.1577  |
# | 11040 | Reigate and Banstead                | South East               |        271 | 10.1206  |
# |  8280 | East Hampshire                      | South East               |        272 | 10.0377  |
# | 10212 | East Hertfordshire                  | East of England          |        273 |  9.96961 |
# |  8763 | Bracknell Forest                    | South East               |        274 |  9.96507 |
# |  8832 | Three Rivers                        | East of England          |        275 |  9.87735 |
# | 10350 | Rutland                             | East Midlands            |        276 |  9.84335 |
# | 20217 | Guildford                           | South East               |        277 |  9.78288 |
# | 13386 | Richmond upon Thames                | London                   |        278 |  9.49132 |
# |  7107 | Horsham                             | South East               |        279 |  9.46397 |
# | 19113 | Mole Valley                         | South East               |        280 |  9.41096 |
# |  5106 | South Cambridgeshire                | East of England          |        281 |  9.34934 |
# | 10074 | Harborough                          | East Midlands            |        282 |  9.29537 |
# | 11385 | Vale of White Horse                 | South East               |        283 |  9.25916 |
# |  7383 | Windsor and Maidenhead              | South East               |        284 |  8.91842 |
# | 15318 | Mid Sussex                          | South East               |        285 |  8.76252 |
# | 19527 | South Oxfordshire                   | South East               |        286 |  8.55748 |
# | 17181 | Waverley                            | South East               |        287 |  8.22221 |
# | 14904 | Fareham                             | South East               |        288 |  8.17447 |
# |  5451 | St Albans                           | East of England          |        289 |  8.09987 |
# | 19941 | Elmbridge                           | South East               |        290 |  8.09391 |
# | 20079 | Epsom and Ewell                     | South East               |        291 |  8.00576 |
# |  6486 | Rushcliffe                          | East Midlands            |        292 |  7.94464 |
# |  7866 | Surrey Heath                        | South East               |        293 |  7.90631 |
# |  8556 | Wokingham                           | South East               |        294 |  5.91117 |
# | 15456 | Hart                                | South East               |        295 |  5.855   |

# %%
la_stats["imd_rank"].max()

# %%
print(
    la_stats.sort_values("pct_change", ascending=False)[
        ["la_name", "region", "pct_change", "imd_rank"]
    ]
    .head(10)
    .assign(pct_change=lambda x: x["pct_change"].astype(int).astype(str) + "%")
    .to_markdown(index=False)
)
# Out:
# | la_name              | region     | pct_change   |   imd_rank |
# |:---------------------|:-----------|:-------------|-----------:|
# | Tameside             | North West | 59%          |         45 |
# | Rossendale           | North West | 53%          |         59 |
# | Rochdale             | North West | 51%          |         20 |
# | Bury                 | North West | 51%          |        104 |
# | Trafford             | North West | 48%          |        201 |
# | Salford              | North West | 48%          |         27 |
# | Oldham               | North West | 47%          |         14 |
# | Folkestone and Hythe | South East | 47%          |         73 |
# | Stockport            | North West | 45%          |        164 |
# | Liverpool            | North West | 45%          |          8 |

# %%
import geopandas as gpd
import pyproj

# Load shapefile - update the path to your shapefile
gdf = gpd.read_file(
    "Local_Authority_Districts_May_2024_Boundaries_UK_BFE_-5758551109064458912/LAD_MAY_2024_UK_BFE.shp"
)

# Merge with your data (assuming area_code matches a column in the shapefile)
gdf = gdf.merge(la_stats, left_on="LAD24CD", right_on="la_code", how="right")

gdf.to_crs(pyproj.CRS.from_epsg(4326), inplace=True)

# Simplify geometries for better performance
gdf["geometry"] = gdf.to_crs(gdf.estimate_utm_crs()).simplify(750).to_crs(gdf.crs)

# %%
import plotly.express as px


# Create custom color scale using corporate colors
# rgb(21, 38, 58) for low, rgb(10, 255, 206) for high
colorscale = [
    [0, "rgb(244, 240, 231)"],  # Beige for lowest
    [0.5, "rgb(10, 255, 206)"],  # Cyan for highest
    [1, "rgb(21, 38, 58)"],  # Dark blue for medium
]

subtitle = "% change in private rent (2020-2025) weighted by average income deprivation score (2025).<br>Higher values indicate greater risk of rent affordability issues."

fig = px.choropleth(
    gdf,
    geojson=gdf.geometry.__geo_interface__,
    locations=gdf.index,
    color="rent_risk_index",
    color_continuous_scale=colorscale,
    labels={"rent_risk_index": "Rent Risk Index"},
    title=f"<b>Rent Risk Index by Local Authority</b><br><sub>{subtitle}</sub>",
    hover_data={
        "la_name": True,
        "region": True,
        "pct_change": ":.1f",
        "income": ":.2f",
        "rent_risk_index": ":.1f",
    },
)

fig.update_traces(
    hovertemplate="<b>%{customdata[0]}</b><br>Region: %{customdata[1]}<br>Rent Change: %{customdata[2]:.1f}%<br>Income Deprivation: %{customdata[3]:.2f}<br>Risk Index: %{customdata[4]:.1f}<extra></extra>"
)

fig.update_geos(
    fitbounds="locations",
    visible=False,
    projection_type="mercator",
    bgcolor="rgb(244, 240, 231)",
)

fig.update_layout(
    # height=800,
    # width=1000,
    margin={"r": 100, "t": 150, "l": 0, "b": 100},
    paper_bgcolor="rgb(244, 240, 231)",
    plot_bgcolor="rgb(244, 240, 231)",
    title=dict(y=0.95, yanchor="top"),
)

fig.show(config={"displayModeBar": False})
fig.write_html("rent_risk_index_map.html", config={"displayModeBar": False})

# %%
# Scatter plot with overall trendline: IMD vs Rent Change
fig = px.scatter(
    la_stats,
    x="imd",
    y="pct_change",
    color="region",
    hover_data=["la_name"],
    title="<b>Higher deprivation scores are associated with faster rent increases</b>",
    labels={
        "imd": "Index of Multiple Deprivation (IMD)",
        "pct_change": "Rent Change 2020-2025 (%)",
    },
    trendline="ols",
    trendline_scope="overall",
)

# Get trendline results
results = px.get_trendline_results(fig)
slope = results.px_fit_results.iloc[0].params[1]
print(f"Slope: {slope:.3f}")
print(
    f"For every 1 unit increase in deprivation (IMD), rent increases by approximately {slope:.1f} percentage points on average."
)

# Update styling to match corporate colors
fig.update_traces(
    marker=dict(size=8, opacity=0.7),
    hovertemplate="<b>%{customdata[0]}</b><br>Region: %{fullData.name}<br>IMD: %{x:.2f}<br>Rent Change: %{y:.1f}%<extra></extra>",
    selector=dict(mode="markers"),
)

# Update trendline styling
fig.update_traces(
    line=dict(color="black", dash="dot", width=2),
    opacity=0.5,
    hovertemplate="Trendline<extra></extra>",
    selector=dict(mode="lines"),
)

# Style layout
fig.update_layout(
    plot_bgcolor="rgb(244, 240, 231)",
    paper_bgcolor="rgb(244, 240, 231)",
    font=dict(size=12),
    title=dict(y=0.95, yanchor="top"),
    margin=dict(t=80, l=60, r=60, b=120),
    showlegend=True,
    legend=dict(
        orientation="h",
        yanchor="top",
        y=-0.2,
        xanchor="center",
        x=0.5,
        title="",
        itemsizing="constant",
        tracegroupgap=0,
    ),
)

# Remove gridlines
fig.update_xaxes(showgrid=False, title_standoff=15)
fig.update_yaxes(showgrid=False, title_standoff=15)

fig.show()
fig.write_html("imd_rent_scatter.html", config={"displayModeBar": False})
# Out:
# Slope: 0.204
# For every 1 unit increase in deprivation (IMD), rent increases by approximately 0.2 percentage points on average.
